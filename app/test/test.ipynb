# %%
import sys
import os

# Récupère le chemin vers green_gym/ depuis app/test/
project_root = os.path.abspath(os.path.join(os.getcwd(), "../.."))
sys.path.insert(0, project_root)

print("✔️ Dossier racine ajouté au sys.path :", project_root)
# Out:
# ✔️ Dossier racine ajouté au sys.path : c:\Users\elkar\OneDrive\Desktop\green_gym

# %%
from app.models import SalleDeSport
print("✔ Import réussi")
# Out:
# ✔ Import réussi
